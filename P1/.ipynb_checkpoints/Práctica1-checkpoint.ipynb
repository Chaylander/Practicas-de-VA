# %% [markdown]
# Impresion en blanco y negro con cv2

# %%
import cv2
import numpy as np
from matplotlib import pyplot as plt

imagen = cv2.imread('desktop1.jpg',cv2.IMREAD_GRAYSCALE)

cv2.imshow('Cuadrito1',imagen)

cv2.waitKey(0)
cv2.destroyAllWindows()

# %% [markdown]
# Impresión a color con matplotlib

# %%
import matplotlib.pyplot as plt
import matplotlib.image as img

image = img.imread('desktop1.jpg')
plt.imshow(image)
plt.show()

# %%
Impresión a blanco y negro con matplotlib

# %%
import numpy as np
import matplotlib.pyplot as plt
from PIL import Image

fname = 'desktop1.jpg'
image = Image.open(fname).convert("L")
arr = np.asarray(image)
plt.imshow(arr, cmap='gray', vmin=0, vmax=255)
plt.show()

# %% [markdown]
# Impresión cambiando la resolución espacial

# %%
import cv2

img = cv2.imread("desktop1.jpg",cv2.IMREAD_GRAYSCALE)

newImg = cv2.resize(img, (0,0), fx=0.3, fy=0.3)

cv2.imshow('Resized Cuadrito1', newImg)

cv2.waitKey(0)
# Out:
# -1

# %% [markdown]
# Cambiando resolución radiometrica

# %%
import cv2
img = cv2.imread("desktop1.jpg")

yuv_img = cv2.cvtColor(img, cv2.COLOR_BGR2YUV)
cv2.imshow('GYUV', gray_img)
cv2.imshow('U channel', yuv_img[:, :, 1])

cv2.waitKey()
